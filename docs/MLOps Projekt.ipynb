# %% [markdown]
# <h3>Detaillierte Beschreibung aller Spalten mit möglichen Werten</h3><br><br>
#
# **1. age (Alter)** <br>
# - Typ: Numerisch <br>
# - Beschreibung: Das Alter der Person in Jahren (integer-Wert)<br><br>
#
#
# **2. workclass (Art der Beschäftigung)**<br>
# - Typ: Kategorisch
# - Beschreibung: Gibt an, in welcher Art von Organisation die Person arbeitet<br>
#
# - **Mögliche Werte:**<br>
# Private -> Privatunternehmen<br>
# Self-emp-not-inc -> Selbstständig (nicht eingetragenes Unternehmen)<br>
# Self-emp-inc -> Selbstständig (eingetragenes Unternehmen)<br>
# Federal-gov -> Bundesregierung<br>
# Local-gov -> Kommunale Regierung<br>
# State-gov -> Landesregierung<br>
# Without-pay -> Unbezahlt arbeitend<br>
# Never-worked -> Noch nie gearbeitet<br><br>
#
#
# **3. fnlwgt (Final Weight)**<br>
# - Typ: Numerisch<br>
# - Beschreibung: Eine Gewichtungsvariable, die angibt, wie viele Personen in der Bevölkerung der Stichprobe entsprechen.<br><br>
#
#
# **4. education (Bildungsabschluss)**<br>
# - Typ: Kategorisch<br>
# - Beschreibung: Höchster Bildungsabschluss der Person<br>
#
# - **Mögliche Werte:**<br>
# Preschool -> Vorschule<br>
# 1st-4th -> 1. bis 4. Schuljahr<br>
# 5th-6th -> 5. bis 6. Schuljahr<br>
# 7th-8th -> 7. bis 8. Schuljahr<br>
# 9th -> 9. Schuljahr<br>
# 10th -> 10. Schuljahr<br>
# 11th -> 11. Schuljahr<br>
# 12th -> 12. Schuljahr<br>
# HS-grad -> High-School-Abschluss<br>
# Some-college -> Teilweise Hochschule<br>
# Assoc-acdm -> Associate Degree (akademisch)<br>
# Assoc-voc -> Associate Degree (beruflich)<br>
# Bachelors -> Bachelor-Abschluss<br>
# Masters -> Master-Abschluss<br>
# Doctorate -> Doktortitel (PhD)<br>
# Prof-school -> Berufsschule<br><br>
#
#
# **5. educational-num (Bildungsjahre, numerisch)**<br>
# - Typ: Numerisch<br>
# - Beschreibung: Die Anzahl der abgeschlossenen Schuljahre. Diese Spalte entspricht education, aber in numerischer Form (z. B. 16 Jahre für ein PhD)<br><br>
#
#
# **6. marital-status (Familienstand)**<br>
# - Typ: Kategorisch<br>
# - Beschreibung: Familienstand der Person<br>
#
# - **Mögliche Werte:**<br>
# Married-civ-spouse -> Verheiratet (zivilrechtlich)<br>
# Married-AF-spouse -> Verheiratet mit einer Person im aktiven Militärdienst<br>
# Divorced -> Geschieden<br>
# Never-married -> Noch nie verheiratet<br>
# Separated -> Getrennt lebend<br>
# Widowed -> Verwitwet<br>
# Married-spouse-absent -> Verheiratet, aber getrennt lebend<br><br>
#
#
# **7. occupation (Berufsfeld)**<br>
# - Typ: Kategorisch<br>
# - Beschreibung: Die Art der beruflichen Tätigkeit<br>
#
# - **Mögliche Werte:**<br>
# Tech-support -> Technischer Support<br>
# Craft-repair -> Handwerks- und Reparaturberufe<br>
# Other-service -> Andere Dienstleistungen<br>
# Sales -> Vertrieb / Verkauf<br>
# Exec-managerial -> Führungskräfte & Management<br>
# Prof-specialty -> Akademische Berufe (z. B. Ärzte, Ingenieure)<br>
# Handlers-cleaners -> Handwerker & Reinigungskräfte<br>
# Machine-op-inspct -> Maschinenführer & Inspektoren<br>
# Adm-clerical -> Verwaltung & Büroarbeit<br>
# Farming-fishing -> Landwirtschaft & Fischerei<br>
# Transport-moving -> Transport & Logistik<br>
# Priv-house-serv -> Haushaltsdienstleistungen<br>
# Protective-serv -> Schutz- & Sicherheitsberufe (Polizei, Feuerwehr)<br>
# Armed-Forces -> Streitkräfte / Militär<br><br>
#
#
# **8. relationship (Beziehung im Haushalt)**<br>
# - Typ: Kategorisch<br>
# - Beschreibung: Die Rolle der Person innerhalb des Haushalts<br>
#
# - **Mögliche Werte:**<br>
# Wife -> Ehefrau<br>
# Husband -> Ehemann<br>
# Own-child -> Eigenes Kind<br>
# Unmarried -> Unverheiratet<br>
# Other-relative -> Anderer Verwandter<br>
# Not-in-family -> Kein Familienmitglied (z. B. Mitbewohner)<br><br>
#
#
# **9. race (Ethnische Zugehörigkeit)**<br>
# - Typ: Kategorisch<br>
# - Beschreibung: Ethnische Zugehörigkeit der Person<br>
#
# - **Mögliche Werte:**<br>
# White -> Weiß<br>
# Black -> Schwarz<br>
# Asian-Pac-Islander -> Asiatisch / Pazifikinseln<br>
# Amer-Indian-Eskimo -> Amerikanische Ureinwohner / Inuit<br>
# Other -> Andere<br><br>
#
#
# **10. gender (Geschlecht)**<br>
# - Typ: Kategorisch<br>
#
# - **Mögliche Werte:**<br>
# Male -> Männlich<br>
# Female -> Weiblich<br><br>
#
#
# **11. capital-gain (Kapitalgewinne)**<br>
# - Typ: Numerisch<br>
# - Beschreibung: Kapitalgewinne in US-Dollar aus Investitionen oder anderen Quellen<br><br>
#
#
# **12. capital-loss (Kapitalverluste)** <br>
# - Typ: Numerisch<br>
# - Beschreibung: Kapitalverluste in US-Dollar<br><br>
#
#
# **13. hours-per-week (Arbeitsstunden pro Woche)** <br>
# - Typ: Numerisch<br>
# - Beschreibung: Durchschnittliche Arbeitsstunden pro Woche<br><br>
#
#
# **14. native-country (Herkunftsland)** <br>
# - Typ: Kategorisch<br>
# - Beschreibung: Das Geburtsland der Person<br>
#
# - **Beispiele:** <br>
# United-States -> Vereinigte Staaten<br>
# Mexico -> Mexiko<br>
# Germany -> Deutschland<br>
# Canada -> Kanada<br>
# India -> Indien<br>
# China -> China<br>
# Philippines -> Philippinen<br>
# England -> England<br>
# Other -> Andere Länder<br><br>
#
#
# **15. income (Zielvariable)**<br>
# - Typ: Kategorisch<br>
# - Beschreibung: Einkommensklasse der Person<br>
#
# - **Mögliche Werte:** <br>
# "<=50K" -> Einkommen beträgt 50.000 USD oder weniger<br>
# ">50K" -> Einkommen beträgt mehr als 50.000 USD<br><br>

# %% [markdown]
# <br><h4>Bibliotheken laden</h4><br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br><h4>Datensatz laden</h4><br>

# %%
df = pd.read_csv("adult.csv")
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# <br><h4>Überblick über die Daten</h4><br>

# %%
# Allgemeine Infos über den Datensatz
df.info()

# Statistische Übersicht für numerische Spalten
df.describe()

# Prüfen auf fehlende Werte
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# age                0
# ...

# %% [markdown]
# Hinweis: Da keine Zellen mit fehlenden Werten existiert, brauchen wir isnull nicht zu befüllen

# %% [markdown]
# <br><h4>Einkommensverteilung visualisieren</h4><br>

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="income", hue="income", palette="coolwarm", legend=False)
plt.title("Verteilung der Einkommensklassen")
plt.xlabel("Einkommen")
plt.ylabel("Anzahl")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Einkommensverteilung**<br><br>
#
# Die Visualisierung zeigt die Verteilung der Einkommensklassen. Dabei wurden zwei Einkommensgruppen untersucht:<br>
#
# - "<=50K": Einkommen ≤ 50.000 USD pro Jahr
# - ">50K": Einkommen > 50.000 USD pro Jahr<br><br>
#
#
# Wichtige Beobachtungen:<br>
# - Unbalancierte Klassenverteilung: Die Mehrheit der Personen verdient ≤50.000 USD pro Jahr (über 35.000 Personen). Nur eine vergleichsweise kleine Gruppe (rund 10.000 Personen) verdient mehr als 50.000 USD jährlich.

# %% [markdown]
# <br><h4>Altersverteilung nach Einkommensklasse</h4><br>

# %%
# Einkommensvariable als String sicherstellen
df["income"] = df["income"].astype(str)

plt.figure(figsize=(10,6))
sns.histplot(data=df, x="age", hue="income", kde=True, bins=30, palette="coolwarm")

# Manuelle Legende
plt.legend(title="Einkommen", labels=["<=50K", ">50K"])

plt.title("Altersverteilung nach Einkommensklasse")
plt.xlabel("Alter")
plt.ylabel("Anzahl")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Altersverteilung nach Einkommensklasse**<br><br>
#
# Diese Visualisierung zeigt die Altersverteilung der Personen in Abhängigkeit von ihrer Einkommensklasse (<=50K vs. >50K).<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Jüngere Personen verdienen größtenteils weniger als 50K USD<br>
# - In den Altersgruppen von 20 bis ca. 35 Jahren dominiert die Einkommensklasse <=50K
# - Das deutet darauf hin, dass viele jüngere Menschen noch nicht genug Berufserfahrung oder Bildungsabschlüsse haben, um in die höhere Einkommensklasse (>50K) zu gelangen.<br><br>
#
# 2. Personen mit hohem Einkommen sind meist älter<br>
# - Die Anzahl der Personen mit Einkommen über 50K USD nimmt mit dem Alter zu, insbesondere ab 35–40 Jahren<br>
# - Das könnte daran liegen, dass Menschen mit mehr Berufserfahrung, höherer Bildung oder in besser bezahlten Führungspositionen in diese Altersgruppe fallen<br><br>
#
# 3. Ab 50 Jahren nimmt die Anzahl beider Einkommensklassen ab<br>
# - Die Anzahl der Personen im Datensatz nimmt ab 50 Jahren deutlich ab<br>
# - Dies könnte darauf hinweisen, dass ältere Menschen sich langsam aus dem Arbeitsmarkt zurückziehen (z. B. Rente)<br>
# - Trotzdem gibt es noch eine nennenswerte Anzahl an Personen über 50 mit Einkommen >50K, was auf gut bezahlte Fachkräfte oder Führungskräfte hindeutet<br><br>
#
# 4. Verteilung der höheren Einkommen ist glatter und breiter verteilt<br>
# - Während die <=50K-Gruppe einen starken Peak in den 20ern hat, ist die >50K-Gruppe flacher und gleichmäßiger verteilt<br>
# - Dies zeigt, dass hohes Einkommen nicht an ein bestimmtes Alter gebunden ist, sondern eher durch andere Faktoren wie Beruf, Bildung und Erfahrung beeinflusst wird<br><br>

# %% [markdown]
# <br><h4>Arbeitsstunden pro Woche nach Einkommensklasse</h4><br>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="income", y="hours-per-week", hue="income", palette="coolwarm")
plt.title("Arbeitsstunden pro Woche nach Einkommensklasse")
plt.xlabel("Einkommen")
plt.ylabel("Arbeitsstunden pro Woche")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Verteilung der Arbeitsstunden pro Woche nach Einkommensklasse**<br><br>
#
# Diese Boxplot-Visualisierung zeigt die Arbeitsstunden pro Woche für Personen in den Einkommensklassen <=50K und >50K.<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Personen mit Einkommen >50K arbeiten tendenziell mehr Stunden pro Woche<br>
# - Die Median-Arbeitszeit für die >50K-Gruppe ist höher als für die <=50K-Gruppe<br>
# - Die Verteilung zeigt, dass viele hochverdienende Personen mehr als 40 Stunden pro Woche arbeiten<br><br>
#
# 2. Personen mit Einkommen <=50K haben eine engere Arbeitszeitverteilung<br>
# - Die Mehrheit arbeitet um die 40 Stunden pro Woche, mit geringerer Varianz<br>
# - Es gibt jedoch einige Personen, die deutlich weniger als 40 Stunden arbeiten<br><br>
#
# 3. Starke Ausreißer in beiden Gruppen<br>
# - Es gibt zahlreiche Ausreißer, insbesondere bei den höheren Arbeitsstunden (>80 Stunden pro Woche)<br>
# - Einige Personen mit sehr wenigen Arbeitsstunden (<10 Stunden pro Woche) sind ebenfalls in den Daten enthalten<br>
# - Diese Ausreißer könnten Teilzeitkräfte oder Personen mit ungewöhnlichen Arbeitszeitmodellen sein<br><br>

# %% [markdown]
# <br><h4>Berufliche Verteilung nach Einkommensklasse</h4><br>

# %%
plt.figure(figsize=(12,6))
sns.countplot(y="occupation", data=df, hue="income", order=df["occupation"].value_counts().index, palette="coolwarm")
plt.title("Berufliche Verteilung nach Einkommensklasse")
plt.xlabel("Anzahl")
plt.ylabel("Beruf")
plt.legend(title="Einkommen")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der beruflichen Verteilung nach Einkommensklasse**<br><br>
#
# Diese Visualisierung zeigt die Verteilung der verschiedenen Berufe im Datensatz, aufgeteilt nach Einkommensklasse (<=50K vs. >50K).<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Bestimmte Berufe sind stärker mit hohem Einkommen verbunden<br>
# - Die Berufe "Exec-managerial" (Führungskräfte & Management) und "Prof-specialty" (Akademische Berufe, z.B. Ärzte, Ingenieure) haben einen hohen Anteil an Personen mit einem Einkommen von über 50K USD<br>
# - Dies deutet darauf hin, dass hochqualifizierte oder leitende Positionen eine höhere Wahrscheinlichkeit für ein Einkommen über 50K haben<br><br>
#
# 2. Viele Berufe sind überwiegend in der <=50K-Kategorie<br>
# - Berufe wie "Other-service" (sonstige Dienstleistungen), "Handlers-cleaners" (Handwerker & Reinigungskräfte), "Transport-moving" (Transport & Logistik), "Farming-fishing" (Landwirtschaft & Fischerei) sind überwiegend in der Einkommensklasse <=50K vertreten<br>
# - Das zeigt, dass diese Berufe in der Regel geringere Löhne haben und es schwieriger ist, in die höhere Einkommensklasse (>50K) zu kommen<br><br>
#
# 3. Unbekannte oder fehlende Berufe (?)<br>
# - Es gibt eine hohe Anzahl von Personen mit einem unbekannten Beruf (?)<br>
# - Es ist unklar, ob diese Personen arbeitslos sind, in Übergangsphasen oder ob Daten fehlen<br>
# - Falls nötig, könnte diese Kategorie in der Datenbereinigung gesondert betrachtet werden<br><br>
#
# 4. Berufe mit einer relativ ausgeglichenen Verteilung<br>
# - Einige Berufe wie "Craft-repair" (Handwerk & Reparatur) und "Tech-support" (Technischer Support) haben sowohl eine große Anzahl in <=50K, aber auch einige in >50K, was darauf hindeutet, dass in diesen Bereichen höhere Löhne mit mehr Erfahrung oder Spezialisierung möglich sind<br><br>

# %% [markdown]
# <br><h4>Geschlechterverteilung nach Einkommensklasse</h4><br>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="gender", data=df, hue="income", palette="coolwarm")
plt.title("Geschlechterverteilung nach Einkommensklasse")
plt.xlabel("Geschlecht")
plt.ylabel("Anzahl")
plt.legend(title="Einkommen")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Geschlechterverteilung nach Einkommensklasse**<br><br>
#
# Diese Visualisierung zeigt die Verteilung von Männern und Frauen im Datensatz in Bezug auf die beiden Einkommensklassen (<=50K und >50K).<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Männer verdienen häufiger mehr als 50K USD als Frauen<br>
# - Der Anteil der Männer mit einem Einkommen über 50K USD ist deutlich höher als der der Frauen<br>
# - Dies könnte auf Faktoren wie Berufswahl, Erfahrung, Arbeitsstunden oder geschlechtsspezifische Unterschiede in der Bezahlung zurückzuführen sein<br><br>
#
# 2. Mehr Frauen sind in der <=50K-Kategorie als in >50K<br>
# - Die Mehrheit der Frauen fällt in die <=50K-Kategorie, und nur ein sehr kleiner Teil hat ein Einkommen über 50K<br>
# - Dies könnte darauf hindeuten, dass Frauen häufiger in Berufen mit niedrigerem Einkommen oder in Teilzeitstellen arbeiten<br><br>
#
# 3. Es gibt insgesamt mehr Männer als Frauen im Datensatz<br>
# - Sowohl in der <=50K- als auch in der >50K-Kategorie gibt es mehr Männer als Frauen<br>
# - Dies könnte darauf hinweisen, dass der Datensatz weniger Frauen als Männer erfasst oder dass Frauen im betrachteten Arbeitsmarkt insgesamt unterrepräsentiert sind<br><br>

# %% [markdown]
# <br><h4>Herkunftsland nach Einkommensklasse</h4><br>

# %%
plt.figure(figsize=(12,6))
sns.countplot(y="native-country", data=df, hue="income", order=df["native-country"].value_counts().index[:10], palette="coolwarm")
plt.title("Herkunftsland nach Einkommensklasse (Top 10)")
plt.xlabel("Anzahl")
plt.ylabel("Herkunftsland")
plt.legend(title="Einkommen", loc="lower right")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Einkommensverteilung nach Herkunftsland**<br><br>
#
# Diese Visualisierung zeigt die Verteilung der Einkommensklassen (<=50K und >50K) basierend auf dem Herkunftsland der Personen.<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Die Mehrheit der Personen stammt aus den USA<br>
# - Die große Mehrheit der Personen im Datensatz stammt aus den Vereinigten Staaten<br>
# - Sowohl die <=50K- als auch die >50K-Kategorie sind dort stark vertreten, jedoch gibt es wesentlich mehr Personen mit niedrigerem Einkommen (<=50K), was den allgemeinen Trend des Datensatzes widerspiegelt<br>
# - Der Anteil der >50K-Verdiener in den USA ist aber trotzdem größer als in anderen Ländern<br><br>
#
# 2. Personen aus anderen Ländern haben überwiegend Einkommen <=50K<br>
# - Länder wie Mexiko, die Philippinen, Puerto Rico, El Salvador, Indien und Kuba haben fast ausschließlich Personen mit Einkommen <=50K<br>
# - Dies deutet darauf hin, dass Einwanderer oder Personen mit ausländischer Herkunft oft in niedrigeren Einkommensgruppen vertreten sind<br>
# - Dies könnte durch verschiedene Faktoren wie Berufswahl, Sprachbarrieren, Qualifikationen oder Einwanderungsstatus beeinflusst werden<br><br>
#
# 3. Deutschland, Kanada und ?-Kategorie haben wenige, aber einige >50K-Verdiener<br>
# - Deutschland und Kanada haben zwar relativ wenige Personen im Datensatz, aber es gibt einige mit Einkommen >50K<br>
# - Die Kategorie ? steht für fehlende oder unbekannte Herkunftsländer, was darauf hindeutet, dass einige Personen keine Herkunftsangabe gemacht haben<br><br>

# %% [markdown]
# <br><h4>Bildungsniveau nach Einkommensklasse</h4><br>

# %%
plt.figure(figsize=(12,6))
sns.countplot(y="education", data=df, hue="income", order=df["education"].value_counts().index, palette="coolwarm")
plt.title("Bildungsniveau nach Einkommensklasse")
plt.xlabel("Anzahl")
plt.ylabel("Bildungsniveau")
plt.legend(title="Einkommen")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Einkommensverteilung nach Bildungsniveau**<br><br>
#
# Diese Visualisierung zeigt die Verteilung des Bildungsniveaus in Bezug auf die beiden Einkommensklassen (<=50K vs. >50K).<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Mehr Bildung führt zu höherem Einkommen<br>
# - Personen mit höherer Bildung (z. B. Bachelors, Masters, Doctorate, Prof-school) haben eine deutlich höhere Wahrscheinlichkeit, mehr als 50K USD zu verdienen<br>
# - Besonders auffällig ist, dass bei Doctorate und Prof-school das Verhältnis von >50K zu <=50K fast ausgeglichen ist, was zeigt, dass akademische Berufe oft mit hohen Gehältern verbunden sind<br><br>
#
# 2. Viele Personen haben nur einen High-School-Abschluss oder waren nur teilweise im College<br>
# - Die Mehrheit der Personen haben einen "HS-grad" (High-School-Abschluss) oder "Some-college" (einige College-Kurse, aber kein Abschluss)<br>
# - Diese Gruppen haben überwiegend ein Einkommen unter 50K<br>
# - Das deutet darauf hin, dass ein High-School-Abschluss allein oft nicht ausreicht, um in die höhere Einkommensklasse zu gelangen<br><br>
#
# 3. Wenig Bildung führt fast immer zu geringem Einkommen<br>
# - Personen mit einem niedrigen Bildungsstand (Preschool, 1st-4th, 5th-6th, 7th-8th) verdienen fast ausschließlich weniger als 50K USD<br>
# - Dies zeigt, dass Bildung ein entscheidender Faktor für höhere Gehälter ist<br><br>
#
# 4. Associate Degrees haben gemischte Einkommen<br>
# - Personen mit einem "Assoc-voc" (beruflicher Associate Degree) oder "Assoc-acdm" (akademischer Associate Degree) befinden sich überwiegend in der <=50K-Kategorie, aber einige verdienen auch mehr als 50K<br>
# - Dies zeigt, dass ein Associate Degree eine mittlere Einkommensstufe ermöglicht, abhängig von der Branche und der Art der Beschäftigung<br><br>

# %% [markdown]
# <br><h4>Familienstand nach Einkommensklasse</h4><br>

# %%
plt.figure(figsize=(12,6))
sns.countplot(y="relationship", data=df, hue="income", order=df["relationship"].value_counts().index, palette="coolwarm")
plt.title("Familienstand nach Einkommensklasse")
plt.xlabel("Anzahl")
plt.ylabel("Familienstand")
plt.legend(title="Einkommen")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Einkommensverteilung nach Familienstand (Relationship)**<br><br>
#
# Diese Visualisierung zeigt, wie sich der Familienstand auf das Einkommen (<=50K vs. >50K) auswirkt.
#
# Wichtige Beobachtungen:<br><br>
# 1. Verheiratete Männer ("Husband") haben die höchste Wahrscheinlichkeit, über 50K zu verdienen<br>
# - Diese Gruppe hat den höchsten Anteil an Personen mit Einkommen >50K<br>
# - Dies könnte darauf hindeuten, dass verheiratete Männer tendenziell in stabileren, höher bezahlten Berufen arbeiten oder mehr Berufserfahrung haben<br><br>
#
# 2. Verheiratete Frauen ("Wife") verdienen seltener über 50K<br>
# - Obwohl es eine >50K-Gruppe gibt, ist sie deutlich kleiner als bei Männern<br>
# - Dies könnte darauf hindeuten, dass verheiratete Frauen häufiger in Teilzeit oder niedriger bezahlten Berufen arbeiten<br><br>
#
# 3. "Not-in-family" und "Unmarried" haben überwiegend Einkommen <=50K<br>
# - Personen, die nicht in einer Familie leben oder ledig sind, verdienen überwiegend unter 50K<br>
# - Dies könnte darauf hindeuten, dass sie jünger sind oder in weniger stabilen Berufsfeldern arbeiten<br><br>
#
# 4. "Own-child" (eigene Kinder) verdienen fast ausschließlich <=50K<br>
# - Diese Gruppe besteht wahrscheinlich aus jungen Erwachsenen oder Studierenden, die noch nicht im Berufsleben stehen<br><br>
#
# 5. "Other-relative" (andere Verwandte) hat eine ähnliche Verteilung wie "Unmarried"<br>
# - Dies zeigt, dass Personen, die als abhängige Familienmitglieder leben, eher niedrigere Einkommen haben<br><br>

# %% [markdown]
# <br><h4>Einkommensverteilung nach Familienstand</h4><br>

# %%
plt.figure(figsize=(12,6))
sns.countplot(y="marital-status", data=df, hue="income", order=df["marital-status"].value_counts().index, palette="coolwarm")
plt.title("Einkommensverteilung nach Familienstand")
plt.xlabel("Anzahl")
plt.ylabel("Familienstand")
plt.legend(title="Einkommen", loc="lower right")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Einkommensverteilung nach Familienstand (marital-status)**<br><br>
#
# Diese Visualisierung zeigt die Verteilung des Familienstands in Bezug auf die Einkommensklassen (<=50K und >50K).<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Verheiratete Personen („Married-civ-spouse“) haben die höchste Wahrscheinlichkeit für ein Einkommen >50K<br>
# - Diese Gruppe zeigt die größte Anzahl an Personen mit hohem Einkommen (>50K)<br>
# - Gleichzeitig gibt es auch viele Personen in dieser Kategorie mit einem Einkommen ≤50K, allerdings ist das Verhältnis zwischen hoher und niedrigerem Einkommen in dieser Gruppe ausgeglichener als bei anderen Kategorien<br><br>
#
# 2. „Never-married“ Personen verdienen überwiegend ≤50K<br>
# - Diese Gruppe ist die zweitgrößte in der Verteilung<br>
# - Der Großteil der Nie-Verheirateten verdient ≤50K, nur ein kleiner Teil gehört zur höheren Einkommensklasse<br>
# - Dies könnte mit Faktoren wie Alter, weniger Berufserfahrung oder fehlender finanzieller Stabilität durch Partnerschaft zusammenhängen<br><br>
#
# 3. Geschiedene („Divorced“), Getrennte („Separated“) und Verwitwete („Widowed“) verdienen größtenteils ≤50K<br>
# - Personen in diesen Kategorien haben nur einen sehr kleinen Anteil an Einkommen >50K<br>
# - Dies könnte mit finanziellen Belastungen durch Trennung oder dem Eintritt ins Rentenalter zusammenhängen<br>
# - Auch fehlende berufliche Entwicklungsmöglichkeiten nach Trennung oder Verlust eines Partners könnten eine Rolle spielen<br><br>
#
# 4. „Married-spouse-absent“ und „Married-AF-spouse“ sind selten vertreten und verdienen überwiegend ≤50K<br>
# - „Married-spouse-absent“ bedeutet, dass die Person verheiratet ist, aber vom Partner getrennt lebt – diese Personen haben fast ausschließlich Einkommen ≤50K<br>
# - „Married-AF-spouse“ bedeutet, dass die Person mit jemandem im aktiven Militärdienst verheiratet ist – auch hier ist das Einkommen überwiegend ≤50K<br><br>

# %% [markdown]
# <br><h4>Einkommensverteilung nach ethnischer Zugehörigkeit</h4><br>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, y="race", hue="income", order=df["race"].value_counts().index, palette="coolwarm")
plt.title("Einkommensverteilung nach ethnischer Zugehörigkeit")
plt.xlabel("Anzahl")
plt.ylabel("Ethnische Zugehörigkeit")
plt.legend(title="Einkommen")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Einkommensverteilung nach ethnischer Zugehörigkeit**<br><br>
#
# Diese Visualisierung zeigt die Verteilung der Einkommensklassen (<=50K und >50K) in Bezug auf die ethnische Zugehörigkeit der Personen im Datensatz.<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Die Mehrheit der Personen gehört zur Kategorie "White"<br>
# - Die größte Gruppe in den Daten ist „White“, mit einem deutlichen Übergewicht an Personen mit einem Einkommen ≤50K<br>
# - Die Anzahl der Personen mit >50K Einkommen ist in dieser Gruppe zwar am höchsten, aber dennoch deutlich kleiner als die Gruppe mit ≤50K Einkommen<br><br>
#
# 2. Andere ethnische Gruppen sind zahlenmäßig kleiner vertreten<br>
# - Die zweitgrößte Gruppe ist „Black“, gefolgt von „Asian-Pac-Islander“<br>
# - Gruppen wie „Amer-Indian-Eskimo“ und „Other“ sind in der Stichprobe sehr gering vertreten<br><br>
#
# 3. Höhere Einkommensklasse (>50K) ist besonders in der Gruppe „White“ stärker vertreten<br>
# - Der Anteil an Personen mit höherem Einkommen (>50K) ist in der Gruppe „White“ im Vergleich zu anderen Gruppen überdurchschnittlich hoch<br>
# - Die Gruppe „Asian-Pac-Islander“ hat relativ betrachtet auch einen höheren Anteil an Personen mit Einkommen >50K als z. B. die Gruppen „Black“ oder „Amer-Indian-Eskimo“<br><br>
#
# 4. Die Gruppen "Black", "Asian-Pac-Islander" und "Other" haben einen wesentlich höheren Anteil an Personen mit Einkommen ≤50K<br>
# - Besonders in der Gruppe „Black“ ist der Anteil der Personen mit niedrigerem Einkommen (≤50K) auffällig hoch<br>
# - In der Gruppe „Asian-Pac-Islander“ gibt es einen kleineren, aber messbaren Anteil an Personen mit einem Einkommen >50K, was auf bessere Chancen in bestimmten Berufen oder Industrien hindeuten könnte<br><br>

# %% [markdown]
# <br><h4>Arbeitsverhältnis nach Branchen (workclass) und Einkommensklasse</h4><br>

# %%
plt.figure(figsize=(12,6))
sns.countplot(y="workclass", data=df, hue="income", order=df["workclass"].value_counts().index, palette="coolwarm")
plt.title("Arbeitsverhältnis nach Einkommensklasse")
plt.xlabel("Anzahl")
plt.ylabel("Arbeitsverhältnis (Workclass)")
plt.legend(title="Einkommen", loc="lower right")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Verteilung des Arbeitsverhältnisses (Workclass) nach Einkommensklasse**<br><br>
#
# Diese Visualisierung zeigt die Verteilung des Arbeitsverhältnisses (Workclass) in Bezug auf die Einkommensklassen (<=50K und >50K).<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Die Mehrheit der Personen arbeitet im privaten Sektor („Private“)
# - Die größte Gruppe ist der private Sektor, mit einem hohen Anteil an Personen mit ≤50K Einkommen<br>
# - Allerdings gibt es auch eine signifikante Anzahl von Personen im privaten Sektor mit Einkommen >50K, jedoch deutlich weniger als mit ≤50K<br><br>
#
# 2. Selbstständige (Self-emp-not-inc & Self-emp-inc) haben höhere Anteile an Einkommen >50K<br>
# - Personen, die eingetragene Selbstständige („Self-emp-inc“) sind, haben einen vergleichsweise hohen Anteil an Einkommen >50K<br>
# - Nicht eingetragene Selbstständige („Self-emp-not-inc“) haben tendenziell geringere Einkommen, da die Mehrheit in dieser Gruppe ≤50K verdient<br><br>
#
# 3. Regierungsangestellte („Local-gov“, „State-gov“, „Federal-gov“) haben eine ausgewogene Einkommensverteilung<br>
# - Personen, die für die Bundesregierung („Federal-gov“) arbeiten, haben im Verhältnis einen höheren Anteil an Einkommen >50K als die, die für kommunale oder Landesregierungen tätig sind<br>
# - Regierungsangestellte im Allgemeinen haben jedoch mehr Sicherheit und stabilere Einkommen<br><br>
#
# 4. „Without-pay“ und „Never-worked“ haben fast ausschließlich Einkommen ≤50K<br>
# - Personen, die ohne Bezahlung arbeiten oder nie gearbeitet haben, gehören fast ausschließlich zur Einkommensklasse ≤50K<br>
# - Das ist wenig überraschend, da ein fehlendes Arbeitsverhältnis den Zugang zu hohem Einkommen stark einschränkt<br><br>

# %% [markdown]
# <br><h4>Bildungsjahre nach Einkommensklasse</h4><br>

# %%
# Sicherstellen, dass die Spalte 'income' als String gespeichert ist
df["income"] = df["income"].astype(str)

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="income", y="educational-num", hue="income", palette="coolwarm")

# Falls die Legende nicht automatisch erscheint, manuell setzen
plt.legend(title="Einkommen", labels=["<=50K", ">50K"])

plt.title("Bildungsjahre nach Einkommensklasse")
plt.xlabel("Einkommen")
plt.ylabel("Bildungsjahre")
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Verteilung der Bildungsjahre nach Einkommensklasse**<br><br>
#
# Diese Visualisierung zeigt die Anzahl der Bildungsjahre (educational-num) für die beiden Einkommensklassen (<=50K und >50K) in einer Boxplot-Darstellung.<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Personen mit höherem Einkommen (>50K) haben in der Regel mehr Bildungsjahre<br>
# - Der Median der >50K-Gruppe liegt bei etwa 11-12 Jahren Bildung (entspricht ungefähr einem Bachelor-Abschluss)<br>
# - Die meisten Personen mit hohem Einkommen haben mindestens 12 Jahre Bildung (High-School-Abschluss) und oft mehr<br><br>
#
# 2. Personen mit niedrigerem Einkommen (<=50K) haben meist weniger als 10 Bildungsjahre<br>
# - Der Median der <=50K-Gruppe liegt bei etwa 10 Jahren Bildung<br>
# - Viele Personen in dieser Gruppe haben weniger als 10 Jahre Bildung, was oft mit niedrigeren Qualifikationen oder Schulabbrüchen korreliert<br><br>
#
# 3. Bildung ist ein entscheidender Faktor für Einkommen<br>
# - Die Boxen zeigen eine deutliche Verschiebung nach oben für die >50K-Gruppe<br>
# - Personen mit mehr als 14-15 Bildungsjahren (z. B. Master- oder Doktortitel) haben fast ausschließlich ein Einkommen über 50K<br><br>
#
# 4. Ausreißer in beiden Gruppen<br>
# - In beiden Gruppen gibt es Ausreißer (Kreise außerhalb der Boxplots)<br>
# - Einige Personen mit sehr niedriger Bildung (<6 Jahre) verdienen dennoch über 50K (evtl. durch Erfahrung oder unternehmerische Tätigkeiten)<br>
# - Ebenso gibt es Personen mit höherer Bildung (>16 Jahre), die dennoch weniger als 50K verdienen (z. B. in schlecht bezahlten akademischen Berufen)<br><br>

# %% [markdown]
# <br><h4>Bildungsjahre nach Einkommensklasse</h4><br>

# %%
# Boxplot für educational-num nach Einkommensklasse
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="income", y="educational-num", hue="income", palette="coolwarm", legend=False)

# Titel und Achsenbeschriftungen setzen
plt.title("Bildungsjahre nach Einkommensklasse")
plt.xlabel("Einkommen")
plt.ylabel("Bildungsjahre (educational-num)")

# Plot anzeigen
plt.show()

# %% [markdown]
# **Erkenntnisse aus der Verteilung der Bildungsjahre (educational-num) nach Einkommensklasse**<br><br>
#
# Diese Boxplot-Visualisierung zeigt, wie die Anzahl der Bildungsjahre (educational-num) mit der Einkommensklasse (<=50K vs. >50K) zusammenhängt.<br>
#
# Wichtige Beobachtungen:<br><br>
# 1. Höheres Bildungsniveau ist mit einem höheren Einkommen verbunden<br>
# - Personen mit Einkommen >50K haben im Durchschnitt mehr Bildungsjahre als diejenigen mit ≤50K<br>
# - Der Median der höherverdienenden Gruppe (>50K) liegt bei etwa 12 oder mehr Jahren Bildung, was typischerweise einem Bachelor- oder Masterabschluss entspricht<br>
# - Der Median der ≤50K-Gruppe liegt bei ca. 9 Jahren, was einem High-School-Abschluss oder weniger entspricht<br><br>
#
# 2. Niedrigere Bildungsjahre sind mit niedrigerem Einkommen assoziiert<br>
# - Personen mit weniger als 9 Jahren Schulbildung sind fast ausschließlich in der ≤50K-Kategorie vertreten<br>
# - Einige wenige Personen mit niedriger Bildung (<5 Jahre) existieren als Ausreißer<br><br>
#
# 3. Starke Überlappung, aber klare Tendenz<br>
# - Während viele Personen mit 10-12 Jahren Bildung in der niedrigen Einkommensklasse bleiben, gibt es einige, die trotz höherer Bildung ≤50K verdienen<br>
# - Dies zeigt, dass Bildung nicht der einzige Faktor für ein hohes Einkommen ist – andere Variablen wie Beruf, Arbeitsstunden und Branche spielen ebenfalls eine Rolle<br><br>
#
# 4. Ausreißer auf beiden Seiten<br>
# - Einige Personen mit sehr wenigen Bildungsjahren (<5) haben ebenfalls ein Einkommen >50K, was auf unternehmerischen Erfolg oder spezielle Berufe hinweisen könnte<br>
# - Es gibt auch einige Personen mit mehr als 16 Jahren Bildung, die trotzdem ≤50K verdienen – möglicherweise betrifft dies akademische Berufe mit niedrigen Einstiegsgehältern<br><br>
